# %%
import pandas as pd

# %%
data1=pd.read_csv("Edited.csv")
data1
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9569    15606229   Obijiaku          771    France    Male   39       5
# 9570    15569892  Johnstone          516    France    Male   35      10
# 9571    15584532        Liu          709    France  Female   36       7
# 9572    15682355  Sabbatini          772   Germany    Male   42       3
# 9573    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
data1.isnull().sum()  ## to drop data1.dropna()
# Out:
# CustomerId            0
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Complain              0
# Satisfaction.Score    0
# Point.Earned          0
# dtype: int64

# %%
data1.describe()
# Out:
#          CustomerId  CreditScore          Age       Tenure        Balance  \
# count  9.574000e+03  9574.000000  9574.000000  9574.000000    9574.000000
# mean   1.569092e+07   650.740547    37.651556     5.015459   76537.282186
# std    7.187697e+04    96.055633     8.639293     2.887850   62419.717438
# min    1.556570e+07   383.000000    18.000000     0.000000       0.000000
# 25%    1.562834e+07   584.000000    32.000000     3.000000       0.000000
# 50%    1.569104e+07   652.000000    37.000000     5.000000   97245.995000
# 75%    1.575305e+07   717.000000    43.000000     7.000000  127653.815000
# max    1.581569e+07   850.000000    61.000000    10.000000  250898.100000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count    9574.000000  9574.000000     9574.000000      9574.000000
# mean        1.530917     0.705557        0.502507    100140.948405
# std         0.580719     0.455816        0.500020     57510.324604
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(data1['Age'])
# Out:
# C:\Users\Usmaan\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ##  Age

# %%
data1[["Age"]].describe(include="all")
# Out:
#                Age
# count  9574.000000
# mean     37.651556
# std       8.639293
# min      18.000000
# 25%      32.000000
# 50%      37.000000
# 75%      43.000000
# max      61.000000

# %%
Q1=data1.Age.quantile(0.25)
Q3=data1.Age.quantile(0.75)
Q1,Q3
# Out:
# (32.0, 43.0)

# %%
IQR=Q3-Q1
IQR
# Out:
# 11.0

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit,upper_limit
# Out:
# (15.5, 59.5)

# %%
data1[(data1.Age<lower_limit)|(data1.Age>upper_limit)]
# Out:
#       CustomerId  Surname  CreditScore Geography  Gender  Age  Tenure  \
# 41      15687946  Osborne          556    France  Female   61       2
# 43      15684171  Bianchi          660     Spain  Female   61       5
# 399     15720559    Heath          487   Germany  Female   61       5
# 403     15810418    T'ang          756   Germany  Female   60       3
# 467     15676519   George          615     Spain    Male   61       9
# ...          ...      ...          ...       ...     ...  ...     ...
# 8996    15639665  Herbert          846     Spain    Male   61       0
# 9129    15717010       Yu          741    France  Female   60       5
# 9187    15724543      Mao          597    France    Male   61       5
# 9340    15736778    Adams          807   Germany  Female   60       1
# 9472    15810563       Ho          678     Spain  Female   61       8
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
data1=data1[(data1.Age>lower_limit)&(data1.Age<upper_limit)]

# %%
data1
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9569    15606229   Obijiaku          771    France    Male   39       5
# 9570    15569892  Johnstone          516    France    Male   35      10
# 9571    15584532        Liu          709    France  Female   36       7
# 9572    15682355  Sabbatini          772   Germany    Male   42       3
# 9573    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
### Credit Score
data1[["CreditScore"]].describe(include="all")
# Out:
#        CreditScore
# count  9460.000000
# mean    650.788266
# std      95.939843
# min     383.000000
# 25%     584.000000
# 50%     652.000000
# 75%     717.000000
# max     850.000000

# %%
Q1=data1.CreditScore.quantile(0.25)
Q3=data1.CreditScore.quantile(0.75)
Q1,Q3
# Out:
# (584.0, 717.0)

# %%
IQR=Q3-Q1
IQR
# Out:
# 133.0

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit,upper_limit
# Out:
# (384.5, 916.5)

# %%
data1[(data1.CreditScore<lower_limit)|(data1.CreditScore>upper_limit)]
# Out:
#       CustomerId Surname  CreditScore Geography  Gender  Age  Tenure  \
# 5255    15642821  Ijendu          383     Spain  Female   48       8
#
#        Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 5255  95808.19              1          0               0         137702.0
#
#       Exited  Complain  Satisfaction.Score  Point.Earned
# 5255       1         1                   1           609

# %%
data1=data1[(data1.CreditScore>lower_limit)&(data1.CreditScore<upper_limit)]

# %%
data1
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9569    15606229   Obijiaku          771    France    Male   39       5
# 9570    15569892  Johnstone          516    France    Male   35      10
# 9571    15584532        Liu          709    France  Female   36       7
# 9572    15682355  Sabbatini          772   Germany    Male   42       3
# 9573    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
data1.to_csv("final.csv", index=False)
